# %%
cd /home/dndx/lihong/op项目/code/code
export PYTORCH_NPU_ALLOC_CONF=expandable_segments:True
export PYTHONNOUSERSITE=1
source fix.sh
torchrun --nproc_per_node=8 --master_addr=localhost --master_port=12355 experiments/S1-2.py 2>&1 | tee /home/dndx/lihong/op项目/outputs/S1-2/logs/run.log
watch -n 1 npu-smi info
